# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense

# %%
import seaborn as sns

# %%
import cv2

# %%
data_eq = np.load('/content/drive/MyDrive/OHRC/subsamples_ohrc_eq_nparray.npy')

# %%
data_s = np.load('/content/drive/MyDrive/OHRC/subsamples_ohrc_south_nparray.npy')

# %%
plt.imshow(data_s[0],cmap='gray')

# %%
plt.hist(data_s[0])
plt.show()

# %%
plt.imshow(data_s[150],cmap='gray')

# %%
plt.hist(data_s[150].flatten(),255,[0,255])
plt.show()

# %%
equ = cv2.equalizeHist(data_s[150])

# %%
plt.imshow(equ,cmap='gray')

# %%
plt.hist(equ.flatten(),255,[0,255])
plt.show()

# %%
clahe = cv2.createCLAHE(clipLimit=4.0, tileGridSize=(8,8))
cl1 = clahe.apply(data_s[150])

# %%
plt.imshow(cl1,cmap='gray')

# %%
clahe = cv2.createCLAHE(clipLimit=8.0, tileGridSize=(8,8))
cl1 = clahe.apply(data_s[150])
plt.imshow(cl1,cmap='gray')

# %%
plt.imshow(data_s[0]+data_s[150],cmap='gray')
